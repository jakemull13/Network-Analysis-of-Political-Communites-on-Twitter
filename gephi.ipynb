# %%
import networkx as nx
from networkx.algorithms import community
import pandas as pd

#G = nx.les_miserables_graph()

# %%
def generate_graph(edge_filepath, node_filepath, title='gephi_graph'):
    edges = pd.read_csv(edge_filepath, header=None)
    nodes = pd.read_csv(node_filepath, header=None)
    edges.columns = ['Source', 'Target']
    nodes.columns = ['Node', 'Alias']
    nodes = nodes.astype('str')
    edges = edges.astype('str')
    edge_tuples = []
    for source, target in zip(edges['Source'], edges['Target']):
        edge_tuples.append((source, target))
    G = nx.DiGraph()
    G.add_nodes_from(nodes['Node'])
    G.add_edges_from(edge_tuples)
    print(nx.info(G))
    nx.write_gexf(G, 'data/gephi' + '/' + title + '.gexf')
    return G

# %%
#nx.to_pandas_edgelist(G)
#nx.to_pandas_adjacency(G)
#nx.write_gexf(G, 'data/gephi/miserables.gexf')

# %%
G = generate_graph('data/democrat/million_convention_mentions/mention-edges-combined.csv', 'data/democrat/million_convention_mentions/mention-nodes.csv', title='large_dconvention')
# Out:
# /Users/jacobmullins/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Name:
# Type: DiGraph
# Number of nodes: 356314
# Number of edges: 947366
# Average in degree:   2.6588
# Average out degree:   2.6588

# %%
G_subgraphs = sorted(nx.connected_component_subgraphs(G.to_undirected()), key=len, reverse=True)
print('Size of largest connected components:', [len(g) for g in G_subgraphs[:20]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-4a8fb065111c> in <module>
# ----> 1 G_subgraphs = sorted(nx.connected_component_subgraphs(G.to_undirected()), key=len, reverse=True)
#       2 print('Size of largest connected components:', [len(g) for g in G_subgraphs[:20]])
#
# AttributeError: module 'networkx' has no attribute 'connected_component_subgraphs'

# %%
largest_cc = max(nx.connected_components(G.to_undirected()), key=len)
largest_cc
# Out:
# {'15264511',
#  '260669899',
#  '1146934770',
#  '65722906',
#  '803768022',
#  '2851570668',
#  '2828812771',
#  '139270676',
#  '3247780708',
#  '8886852',
#  '27749419',
#  '56198162',
#  '2527967047',
#  '4654422329',
#  '39159188',
#  '453598285',
#  '4836059824',
#  '2257188564',
#  '41941546',
#  '554954877',
#  '14630585',
#  '114246723',
#  '197414738',
#  '985039844',
#  '711057600746487808',
#  '353795240',
#  '3017141633',
#  '3030098163',
#  '342109221',
#  '2956920126',
#  '21130667',
#  '17859893',
#  '348133260',
#  '533761016',
#  '114186459',
#  '728444899750612992',
#  '382714825',
#  '318542975',
#  '810299484',
#  '85941136',
#  '3010279711',
#  '705648352227041281',
#  '41668297',
#  '567472873',
#  '240879503',
#  '2832642293',
#  '2490933968',
#  '2984414443',
#  '717698852275503104',
#  '354019560',
#  '92075232',
#  '18155266',
#  '175121933',
#  '2455747996',
#  '3303274047',
#  '35535716',
#  '87173296',
#  '758411435437326336',
#  '2159303565',
# ...

# %%
list(nx.connected_components(G.to_undirected()))
# Out:
# [{'Id'},
#  {'60912113', '7874982'},
#  {'15264511',
#   '260669899',
#   '1146934770',
#   '65722906',
#   '803768022',
#   '2851570668',
#   '2828812771',
#   '139270676',
#   '3247780708',
#   '8886852',
#   '27749419',
#   '56198162',
#   '2527967047',
#   '4654422329',
#   '39159188',
#   '453598285',
#   '4836059824',
#   '2257188564',
#   '41941546',
#   '554954877',
#   '14630585',
#   '114246723',
#   '197414738',
#   '985039844',
#   '711057600746487808',
#   '353795240',
#   '3017141633',
#   '3030098163',
#   '342109221',
#   '2956920126',
#   '21130667',
#   '17859893',
#   '348133260',
#   '533761016',
#   '114186459',
#   '728444899750612992',
#   '382714825',
#   '318542975',
#   '810299484',
#   '85941136',
#   '3010279711',
#   '705648352227041281',
#   '41668297',
#   '567472873',
#   '240879503',
#   '2832642293',
#   '2490933968',
#   '2984414443',
#   '717698852275503104',
#   '354019560',
#   '92075232',
#   '18155266',
#   '175121933',
#   '2455747996',
# ...
